# %% [markdown]
# <a href="https://colab.research.google.com/github/daviddb31/daviddb31/blob/main/firstColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello computational world")
# Out:
# hello computational world

# %%
# %%file simualtion_data.txt
# This is the content of my simulation file.
# Initial velocity =0
# Out:
# Writing simualtion_data.txt

# %%
# !cat simualtion_data.txt
# Out:
# This is the content of my simulation file.
# Initial velocity =0
